# %%
print("OK")
# Out:
# OK

# %% [markdown]
# ###### Data Link: https://www.kaggle.com/datasets/ra4u12/bookrecommendation

# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv(
    r'D:\projects\End-to-End-Book-Recommendation-System\notebooks\BX-Books.csv',
    sep=';',
    encoding='latin-1',
    on_bad_lines='skip'
)
# Out:
# C:\Users\V R VIJAYA LAKSHMI\AppData\Local\Temp\ipykernel_1244\3234422031.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.iloc[10]['Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0771074670.01.LZZZZZZZ.jpg'

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN','Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
# Lets remane some wierd columns name
books.rename(columns={"Book-Title":'title',
                      'Book-Author':'author',
                     "Year-Of-Publication":'year',
                     "Publisher":"publisher",
                     "Image-URL-L":"image_url"},inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            image_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
# Now load the second dataframe
users = pd.read_csv(
    r'D:\projects\End-to-End-Book-Recommendation-System\notebooks\BX-Users.csv',
    sep=';',
    encoding='latin-1',
    on_bad_lines='skip'
)

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
# Lets remane some wierd columns name
users.rename(columns={"User-ID":'user_id',
                      'Location':'location',
                     "Age":'age'},inplace=True)

# %%
users.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
# Now load the third dataframe
ratings = pd.read_csv(
    r'D:\projects\End-to-End-Book-Recommendation-System\notebooks\BX-Book-Ratings.csv',
    sep=';',
    encoding='latin-1',
    on_bad_lines='skip'
)

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
# Lets remane some wierd columns name
ratings.rename(columns={"User-ID":'user_id',
                      'Book-Rating':'rating'},inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
print(books.shape, users.shape, ratings.shape, sep='\n')
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
# Lets store users who had at least rated more than 200 books
x = ratings['user_id'].value_counts() > 200

# %%
x
# Out:
# user_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y= x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
# Now join ratings with books

ratings_with_books = ratings.merge(books, on='ISBN')

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                            image_url
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
number_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.head()
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
number_rating.rename(columns={'rating':'num_of_rating'},inplace=True)

# %%
number_rating.head()
# Out:
#                                                title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              2
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Beyond IBM: Leadership Marketing and Finance ...              1
# 4   Clifford Visita El Hospital (Clifford El Gran...              1

# %%
final_rating = ratings_with_books.merge(number_rating, on='title')

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                            image_url  num_of_rating
# ...

# %%
# Lets take those books which got at least 50 rating of user

final_rating = final_rating[final_rating['num_of_rating'] >= 50]

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                            image_url  num_of_rating
# ...

# %%
# lets drop the duplicates
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.isnull().sum()
# Out:
# user_id          0
# ISBN             0
# rating           0
# title            0
# author           0
# year             0
# publisher        0
# image_url        0
# num_of_rating    0
# dtype: int64

# %%
# Lets create a pivot table
book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14942 stored elements in Compressed Sparse Row format>

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm= 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot.iloc[237,:]
# Out:
# user_id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    9.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: Harry Potter and the Chamber of Secrets (Book 2), Length: 888, dtype: float64

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6 )
#
# File c:\Users\V R VIJAYA LAKSHMI\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:822, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     815 use_pairwise_distances_reductions = (
#     816     self._fit_method == "brute"
#     817     and ArgKmin.is_usable_for(
#     818         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     819     )
#     820 )
#     821 if use_pairwise_distances_reductions:
# --> 822     results = ArgKmin.compute(
#     823         X=X,
#     824         Y=self._fit_X,
#     825         k=n_neighbors,
#     826         metric=self.effective_metric_,
#     827         metric_kwargs=self.effective_metric_params_,
# ...

# %%
distance

# %%
import numpy as np
np.__config__.show()
# Out:
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /c/opt/64/include
#     lib directory: /c/opt/64/lib
#     name: openblas64
#     openblas configuration: USE_64BITINT=1 DYNAMIC_ARCH=1 DYNAMIC_OLDER= NO_CBLAS=
#       NO_LAPACK= NO_LAPACKE= NO_AFFINITY=1 USE_OPENMP= SKYLAKEX MAX_THREADS=2
#     pc file directory: C:/opt/64/lib/pkgconfig
#     version: 0.3.23.dev
#   lapack:
#     detection method: internal
#     found: true
#     include directory: unknown
#     lib directory: unknown
#     name: dep2270588361616
#     openblas configuration: unknown
#     pc file directory: unknown
#     version: 1.26.4
# Compilers:
#   c:
#     commands: cl
#     linker: link
#     name: msvc
#     version: 19.29.30153
#   c++:
#     commands: cl
#     linker: link
#     name: msvc
#     version: 19.29.30153
#   cython:
#     commands: cython
#     linker: cython
#     name: cython
#     version: 3.0.8
# Machine Information:
#   build:
# ...

# %%
suggestion

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])

# %%
#keeping books name
book_names = book_pivot.index

# %%
book_names
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %%
book_names[4]
# Out:
# '84 Charing Cross Road'

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                            image_url  num_of_rating
# ...

# %%
np.where(book_pivot.index == '4 Blondes')[0][0]
# Out:
# 3

# %%
# final_rating['title'].value_counts()
ids = np.where(final_rating['title'] == "Harry Potter and the Chamber of Secrets (Book 2)")[0][0]

# %%
final_rating.iloc[ids]['image_url']
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'

# %%
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 book_name = []
# ----> 2 for book_id in suggestion:
#       3     book_name.append(book_pivot.index[book_id])
#
# NameError: name 'suggestion' is not defined

# %%
book_name

# %%
ids_index = []
for name in book_name[0]: 
    ids = np.where(final_rating['title'] == name)[0][0]
    ids_index.append(ids)

# %%
ids_index

# %%
for idx in ids_index:
    url = final_rating.iloc[idx]['image_url']
    print(url)

# %%
import pickle
pickle.dump(model,open(r'D:\projects\End-to-End-Book-Recommendation-System\artifacts\model.pkl','wb'))
pickle.dump(book_names,open(r'D:\projects\End-to-End-Book-Recommendation-System\artifacts\book_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 import pickle
#       2 pickle.dump(model,open(r'D:\projects\End-to-End-Book-Recommendation-System\artifacts\model.pkl','wb'))
# ----> 3 pickle.dump(book_names,open(r'D:\projects\End-to-End-Book-Recommendation-System\artifacts\book_names.pkl','wb'))
#       4 pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
#       5 pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))
#
# NameError: name 'book_names' is not defined

# %%
book_names

# %% [markdown]
# # Testing model

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6 )
    
    for i in range(len(suggestion)):
            books = book_pivot.index[suggestion[i]]
            for j in books:
                if j == book_name:
                    print(f"You searched '{book_name}'\n")
                    print("The suggestion books are: \n")
                else:
                    print(j)

# %%
book_name = "2nd Chance"
recommend_book(book_name)
